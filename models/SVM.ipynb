# %%
import pandas as pd
import numpy as np
import scipy 
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics
# %matplotlib inline 

from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
csv = '/home/shikha/Documents/PS1/COVID-19/notebooks/clean_df.csv'
df = pd.read_csv(csv)
df.drop(columns=['Unnamed: 0'],inplace=True)
df
# Out:
#      Sample No.      Patient ID          Study ID       Age  Gender       BMI  \
# 0          1013  IGIB1040201013  IGIB1040201013-1  0.551724       1  0.436782
# 1          1014  IGIB1040201014  IGIB1040201014-1  0.241379       0  0.804598
# 2          1015  IGIB1040201015  IGIB1040201015-1  0.264368       1  0.402299
# 3          1016  IGIB1040201016  IGIB1040201016-1  0.781609       1  0.321839
# 4          1060  IGIB1040201060  IGIB1040201060-1  0.505747       1  1.000000
# ..          ...             ...               ...       ...     ...       ...
# 170         950   IGIB104020950   IGIB104020950-1  0.551724       1  0.977011
# 171         965   IGIB104020965   IGIB104020965-1  0.321839       1  0.839080
# 172        9667  IGIB1040209667  IGIB1040209667-1  0.747126       1  0.310345
# 173        9759  IGIB1040209759  IGIB1040209759-1  0.689655       0  0.425287
# 174        9766  IGIB1040209766  IGIB1040209766-1  0.804598       1  0.862069
#
#               Symptoms Presented  Symptoms Present?  Fever  Cough  ...  \
# 0    fever, cough,breathlessness                  1      1      1  ...
# 1                   asymptomatic                  0      0      0  ...
# 2                   asymptomatic                  0      0      0  ...
# 3    fever, cough,breathlessness                  1      1      1  ...
# 4                    fever,cough                  1      1      1  ...
# ..                           ...                ...    ...    ...  ...
# 170  fever, cough,breathlessness                  1      1      1  ...
# 171  fever, cough,breathlessness                  1      1      1  ...
# 172        fever, breathlessness                  1      1      0  ...
# 173     breathlessness and cough                  1      0      1  ...
# 174        fever, breathlessness                  1      1      0  ...
#
#      ALKALINE PHOSPHATASE  C-REACTIVE PROTEINS                ECG     CXR  \
# 0                0.127089             0.152271       sinus rhythm  normal
# 1                0.172501             0.009346       sinus rhythm  normal
# 2                0.259224             0.026437       sinus rhythm  normal
# 3                0.366446             0.443161       sinus rhythm  normal
# 4                0.546200             0.430297       sinus rhythm  normal
# ..                    ...                  ...                ...     ...
# 170              0.219174             0.334734       sinus rhythm  normal
# 171              0.169032             0.362431  sinus tachycardia  normal
# 172              0.177547             0.375164       sinus rhythm  normal
# 173              0.669190             0.325282       sinus rhythm  normal
# 174              1.000000             0.428065       sinus rhythm  normal
#
#      CORADS SCORE ON HRCT  PATIENT CATEGORY  PLASMA THERAPY  Age Above 60?  \
# 0                     4.0                5a              No              0
# 1                     0.0                5b              No              0
# 2                     0.0                5b              No              0
# 3                     5.0                 4              No              1
# 4                     5.0                 4              No              0
# ..                    ...               ...             ...            ...
# 170                   5.0                 4              No              0
# 171                   5.0                 4              No              0
# 172                   5.0                 4              No              1
# 173                   6.0                 4              No              1
# 174                   NaN                 4              No              1
#
#      Temp Groups  CORADS 6
# 0            0.2       0.0
# 1            0.6       0.0
# 2            0.4       0.0
# 3            0.4       0.0
# 4            0.8       0.0
# ..           ...       ...
# 170          0.6       0.0
# 171          0.6       0.0
# 172          0.4       0.0
# 173          0.6       1.0
# 174          0.6       NaN
#
# [175 rows x 62 columns]

# %%
def visualize(x,y, model):
    
        cm = metrics.confusion_matrix(y, model.predict(x))
        plt.figure
        sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
        plt.ylabel('Actual label');
        plt.xlabel('Predicted label');
        plt.savefig('covidseverity.png')
    
        
        
def ttmodel(X, Y, lm, n):
    
        train_accuracy = [0]*n
        train_precision = [0]*n
        train_recall = [0]*n
        train_f1 = [0]*n

        test_accuracy = [0]*n
        test_precision = [0]*n
        test_recall = [0]*n
        test_f1 = [0]*n
        
        for i in range(n):
            x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20)

            lm.fit(x_train,y_train)

            train_accuracy[i] = lm.score(x_train,y_train)
            train_precision[i], train_recall[i], train_f1[i], s = sklearn.metrics.precision_recall_fscore_support(y_train, lm.predict(x_train), average='binary', zero_division=1)

            test_accuracy[i] = lm.score(x_test,y_test)
            test_precision[i], test_recall[i], test_f1[i], s = sklearn.metrics.precision_recall_fscore_support(y_test, lm.predict(x_test), average='binary', zero_division=1)

        print("Average training statistics over",n,"runs of this model - ")
        print("Accuracy Score = ", sum(train_accuracy)/n)
        print("Precision Score = ", sum(train_precision)/n)    
        print("Recall Score = ", sum(train_recall)/n)   
        print("F1 Score = ", sum(train_f1)/n) 

        print()
        
        print("Average testing statistics over",n,"runs of this model - ")
        print("Accuracy Score = ", sum(test_accuracy)/n)
        print("Precision Score = ", sum(test_precision)/n)    
        print("Recall Score = ", sum(test_recall)/n)   
        print("F1 Score = ", sum(test_f1)/n) 
        
        visualize(x_test, y_test, lm)
        
        
def cvmodel(X, Y, lm, cv):
    
        from sklearn.model_selection import cross_validate
        scoring = ['f1','roc_auc']
        scores = cross_validate(lm, X, Y, cv=cv, scoring = scoring, return_train_score=True)
        
        for k,v in scores.items():
            ans = [min(v),sum(v)/len(v),max(v)]
            print(k,"=",ans)
            print()

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', random_state = 1)

#Maybe - Temp, SPO2, TOTAL PROTEINS, SODIUM
X = df[['Age Above 60?','Gender','Temp Groups','Respiratory rate(breaths per minute)','Symptoms Present?','Co-morbidity?','Cough','Breathlessness','Hypertension','C-REACTIVE PROTEINS','UREA']]
Y = df['Outcome']

ttmodel(X, Y, svm, 100)
# Out:
# Average training statistics over 100 runs of this model -
# Accuracy Score =  0.9327857142857146
# Precision Score =  0.841426497565042
# Recall Score =  0.6032938284849714
# F1 Score =  0.6938748163795893
#
# Average testing statistics over 100 runs of this model -
# Accuracy Score =  0.9008571428571416
# Precision Score =  0.7364642857142855
# Recall Score =  0.517603896103896
# F1 Score =  0.5503148518148514

# %%
cvmodel(X, Y, svm, 7)
# Out:
# fit_time = [0.0026810169219970703, 0.003702878952026367, 0.006860256195068359]
#
# score_time = [0.004671573638916016, 0.005601644515991211, 0.008526086807250977]
#
# test_f1 = [0.3333333333333333, 0.5816326530612245, 0.6666666666666666]
#
# train_f1 = [0.6470588235294117, 0.741986482226609, 0.8333333333333333]
#
# test_roc_auc = [0.8484848484848485, 0.9495980210265925, 1.0]
#
# train_roc_auc = [0.953076923076923, 0.9614511254710589, 0.9811738648947952]
